# %% [markdown]
# # Mini Capstone Project
# A fictional telco company that provided home phone and Internet services to 7043
# customers in California in Quarter 3 of the fiscal year.

# %%
#importing required libraries
import pandas as pd #importing panda library  for  data analysis
import numpy as np  #importing numpy library  for mathematical operations
import matplotlib.pyplot as plt  # matplotlib work like MATLAB for graphs
import seaborn as sns    # importing seaborn library for data visualization
# %matplotlib inline
import statistics as st

# %%
#loading the data set
df=pd.read_csv("Telco_customer_churn_Data.csv")  # reading the data
df  #DATA SET
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# ...

# %% [markdown]
# Data Description
#
# •	CustomerID: A unique ID that identifies each customer.
#
# •	Count: A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
#
# •	Country: The country of the customer’s primary residence.
#
# •	State: The state of the customer’s primary residence.
#
# •	City: The city of the customer’s primary residence.
#
# •	Zip Code: The zip code of the customer’s primary residence.
#
# •	Lat Long: The combined latitude and longitude of the customer’s primary residence.
#
# •	Latitude: The latitude of the customer’s primary residence.
#
# •	Longitude: The longitude of the customer’s primary residence.
#
# •	Gender: The customer’s gender: Male, Female
#
# •	Senior Citizen: Indicates if the customer is 65 or older: Yes, No
#
# •	Partner: Indicate if the customer has a partner: Yes, No
#
# •	Dependents: Indicates if the customer lives with any dependents: Yes, No. Dependents could be children, parents,
# grandparents, etc.
#
# •	Tenure Months: Indicates the total amount of months that the customer has been with the company by the end of the quarter specified above.
#
# •	Phone Service: Indicates if the customer subscribes to home phone service with the company: Yes, No
#
# •	Multiple Lines: Indicates if the customer subscribes to multiple telephone lines with the company: Yes, No
#
# •	Internet Service: Indicates if the customer subscribes to Internet service with the company: No, DSL, Fiber Optic, Cable.
#
# •	Online Security: Indicates if the customer subscribes to an additional online security service provided by the company: Yes, No
#
#
# •	Online Backup: Indicates if the customer subscribes to an additional online backup service provided by the company: Yes, No
#
# •	Device Protection: Indicates if the customer subscribes to an additional device protection plan for their Internet equipment provided by the company: Yes, No
#
#
# •	Tech Support: Indicates if the customer subscribes to an additional technical support plan from the company with reduced wait times: Yes, No
#
# •	Streaming TV: Indicates if the customer uses their Internet service to stream television programing from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# •	Streaming Movies: Indicates if the customer uses their Internet service to stream movies from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# •	Contract: Indicates the customer’s current contract type: Month-to-Month, One Year, Two Year.
#
# •	Paperless Billing: Indicates if the customer has chosen paperless billing: Yes, No
#
# •	Payment Method: Indicates how the customer pays their bill: Bank Withdrawal, Credit Card, Mailed Check
#
# •	Monthly Charge: Indicates the customer’s current total monthly charge for all their services from the company.
#
# •	Total Charges: Indicates the customer’s total charges, calculated to the end of the quarter specified above.
#
# •	Churn Label: Yes = the customer left the company this quarter. No = the customer remained with the company. Directly
# related to Churn Value.
#
# •	Churn Value: 1 = the customer left the company this quarter. 0 = the customer remained with the company. Directly related to Churn Label.
#
# •	Churn Score: A value from 0-100 that is calculated using the predictive tool IBM SPSS Modeler. The model incorporates
# multiple factors known to cause churn. The higher the score, the more likely the customer will churn.
#
# •	CLTV: Customer Lifetime Value. A predicted CLTV is calculated using corporate formulas and existing data. The higher the value, the more valuable the customer. High value customers should be monitored for churn.
#
# •	Churn Reason: A customer’s specific reason for leaving the company. Directly related to Churn Category.

# %%
df1=df.copy() #deep copy[Any change in one variable doesn't impact other variable.]

# %%
df.shape #shape of the data set
# Out:
# (7043, 33)

# %%
df.head() #head of the data set
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
df.tail() #tail of the data set
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# 7038  34.341737, -116.539416  34.341737 -116.539416  Female  ...
# 7039  34.667815, -117.536183  34.667815 -117.536183    Male  ...
# 7040  34.559882, -115.637164  34.559882 -115.637164  Female  ...
# 7041     34.1678, -116.86433  34.167800 -116.864330  Female  ...
# 7042  34.424926, -117.184503  34.424926 -117.184503    Male  ...
#
#             Contract Paperless Billing             Payment Method  \
# ...

# %% [markdown]
# # 1. Please read the file and explain data types statistically as well as how python is reading it. Please let us know if any data type is read wrong.

# %%
#Firstly we are going to find that how data is reading in statistically.Later will check for python.

# %%
#In statistically
"""CustomerID        NOMINAL(CATEGORICAL)DATA TYPE       
Count                DISCRETE(NUMERICAL)DATA TYPE
Country              NOMINAL(CATEGORICAL)DATA TYPE
State                NOMINAL(CATEGORICAL)DATA TYPE
City                 NOMINAL(CATEGORICAL)DATA TYPE
Zip Code             DISCRETE(NUMERICAL)DATA TYPE
Lat Long             CONTINUOUS(NUMERICAL)DATA TYPE
Latitude             CONTINUOUS(NUMERICAL)DATA TYPE
Longitude            CONTINUOUS(NUMERICAL)DATA TYPE
Gender               NOMINAL(CATEGORICAL)DATA TYPE
Senior Citizen       NOMINAL(CATEGORICAL)DATA TYPE
Partner              NOMINAL(CATEGORICAL)DATA TYPE
Dependents           NOMINAL(CATEGORICAL)DATA TYPE
Tenure Months        DISCRETE(NUMERICAL)DATA TYPE
Phone Service        NOMINAL(CATEGORICAL)DATA TYPE
Multiple Lines       NOMINAL(CATEGORICAL)DATA TYPE
Internet Service     NOMINAL(CATEGORICAL)DATA TYPE
Online Security      NOMINAL(CATEGORICAL)DATA TYPE
Online Backup        NOMINAL(CATEGORICAL)DATA TYPE
Device Protection    NOMINAL(CATEGORICAL)DATA TYPE
Tech Support         NOMINAL(CATEGORICAL)DATA TYPE
Streaming TV         NOMINAL(CATEGORICAL)DATA TYPE
Streaming Movies     NOMINAL(CATEGORICAL)DATA TYPE
Contract             NOMINAL(CATEGORICAL)DATA TYPE
Paperless Billing    NOMINAL(CATEGORICAL)DATA TYPE
Payment Method       NOMINAL(CATEGORICAL)DATA TYPE
Monthly Charges      CONTINUOUS(NUMERICAL)DATA TYPE
Total Charges        CONTINUOUS(NUMERICAL)DATA TYPE
Churn Label          NOMINAL(CATEGORICAL)DATA TYPE
Churn Value          NOMINAL(CATEGORICAL)DATA TYPE
Churn Score          DISCRETE(NUMERICAL)DATA TYPE
CLTV                 DISCRETE(NUMERICAL)DATA TYPE
Churn Reason         NOMINAL(CATEGORICAL)DATA TYPE """
# Out:
# 'CustomerID        NOMINAL(CATEGORICAL)DATA TYPE       \nCount                DISCRETE(NUMERICAL)DATA TYPE\nCountry              NOMINAL(CATEGORICAL)DATA TYPE\nState                NOMINAL(CATEGORICAL)DATA TYPE\nCity                 NOMINAL(CATEGORICAL)DATA TYPE\nZip Code             DISCRETE(NUMERICAL)DATA TYPE\nLat Long             CONTINUOUS(NUMERICAL)DATA TYPE\nLatitude             CONTINUOUS(NUMERICAL)DATA TYPE\nLongitude            CONTINUOUS(NUMERICAL)DATA TYPE\nGender               NOMINAL(CATEGORICAL)DATA TYPE\nSenior Citizen       NOMINAL(CATEGORICAL)DATA TYPE\nPartner              NOMINAL(CATEGORICAL)DATA TYPE\nDependents           NOMINAL(CATEGORICAL)DATA TYPE\nTenure Months        DISCRETE(NUMERICAL)DATA TYPE\nPhone Service        NOMINAL(CATEGORICAL)DATA TYPE\nMultiple Lines       NOMINAL(CATEGORICAL)DATA TYPE\nInternet Service     NOMINAL(CATEGORICAL)DATA TYPE\nOnline Security      NOMINAL(CATEGORICAL)DATA TYPE\nOnline Backup        NOMINAL(CATEGORICAL)DATA TYPE\nDevic
# ...

# %%
#In Python 
df.dtypes # It gives the type of the data.
# Out:
# CustomerID            object
# Count                  int64
# Country               object
# State                 object
# City                  object
# Zip Code               int64
# Lat Long              object
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn Label           object
# Churn Value            int64
# Churn Score            int64
# CLTV                   int64
# ...

# %%
#or

# %%
df.info() # It gives the type of the data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %% [markdown]
# ###Q1.Explanation:
# After reading the data type statistically and comparing it with python i found that some of the data is wrongly read by the python.
#
# They are:
#
# 1.Lat Long:It is read as object in python but it is a float value.
#
# 2.Total Charges:It is read as object in python but it is a float value.
#
# 3.Churn Value:It is read as int in python but it is a object value.

# %% [markdown]
# # 2. Please apply appropriate statistical measures using python based on data types.

# %%
df.describe()
# Out:
#         Count      Zip Code     Latitude    Longitude  Tenure Months  \
# count  7043.0   7043.000000  7043.000000  7043.000000    7043.000000
# mean      1.0  93521.964646    36.282441  -119.798880      32.371149
# std       0.0   1865.794555     2.455723     2.157889      24.559481
# min       1.0  90001.000000    32.555828  -124.301372       0.000000
# 25%       1.0  92102.000000    34.030915  -121.815412       9.000000
# 50%       1.0  93552.000000    36.391777  -119.730885      29.000000
# 75%       1.0  95351.000000    38.224869  -118.043237      55.000000
# max       1.0  96161.000000    41.962127  -114.192901      72.000000
#
#        Monthly Charges  Churn Value  Churn Score         CLTV
# count      7043.000000  7043.000000  7043.000000  7043.000000
# mean         64.761692     0.265370    58.699418  4400.295755
# std          30.090047     0.441561    21.525131  1183.057152
# min          18.250000     0.000000     5.000000  2003.000000
# ...

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Count                  1.000000
# Zip Code           93552.000000
# Latitude              36.391777
# Longitude           -119.730885
# Tenure Months         29.000000
# Monthly Charges       70.350000
# Churn Value            0.000000
# Churn Score           61.000000
# CLTV                4527.000000
# dtype: float64

# %% [markdown]
# ##Q2 Explanation:
# Statistical measures are nothing but Measures of Central tentency and Dispersion.
#
# Central tendency:
#
# 1.Mean
#
# 2.Median
#
# 3.Mode
#
# Dispersion:
#
# 1.Variance
#
# 2.Standarad Deviation
#
# 3.Range
#
# 4.Skewness
#
# As per the 1st qns we are not calculating the Mean and Median for the nominal level data.But we can calculate Mode for the nominal level data as it has no rank or order.
# Now I'm going to calculate(Mean,Median and Mode)for 1 Numerical column.

# %%
count=df["Count"]
count
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7038    1
# 7039    1
# 7040    1
# 7041    1
# 7042    1
# Name: Count, Length: 7043, dtype: int64

# %%
count.mean()
# Out:
# 1.0

# %%
count.median()
# Out:
# 1.0

# %%
count.mode()
# Out:
# 0    1
# dtype: int64

# %% [markdown]
# #Q2 Explanation:
# Now am going to calculate mode operation for 1Nominal level data type column.

# %%
customer_id=df["CustomerID"]
customer_id
# Out:
# 0       3668-QPYBK
# 1       9237-HQITU
# 2       9305-CDSKC
# 3       7892-POOKP
# 4       0280-XJGEX
#            ...
# 7038    2569-WGERO
# 7039    6840-RESVB
# 7040    2234-XADUH
# 7041    4801-JZAZL
# 7042    3186-AJIEK
# Name: CustomerID, Length: 7043, dtype: object

# %%
customer_id.mode()
# Out:
# 0       0002-ORFBO
# 1       0003-MKNFE
# 2       0004-TLHLJ
# 3       0011-IGKFF
# 4       0013-EXCHZ
#            ...
# 7038    9987-LUTYD
# 7039    9992-RRAMN
# 7040    9992-UJOEL
# 7041    9993-LHIEB
# 7042    9995-HOTOH
# Length: 7043, dtype: object

# %%
df.describe(include=["object"])
# Out:
#         CustomerID        Country       State         City  \
# count         7043           7043        7043         7043
# unique        7043              1           1         1129
# top     3668-QPYBK  United States  California  Los Angeles
# freq             1           7043        7043          305
#
#                       Lat Long Gender Senior Citizen Partner Dependents  \
# count                     7043   7043           7043    7043       7043
# unique                    1652      2              2       2          2
# top     33.964131, -118.272783   Male             No      No         No
# freq                         5   3555           5901    3641       5416
#
#        Phone Service  ... Device Protection Tech Support Streaming TV  \
# count           7043  ...              7043         7043         7043
# unique             2  ...                 3            3            3
# top              Yes  ...                No           No           No
# ...

# %% [markdown]
# #3.What is the percentage of females and senior citizens in this data set? Please create appropriate plots and explain the plots.

# %%
female_no=df['Gender'].tolist().count('Female') #CALCULATING FEMLAE NUMBER
female_no
# Out:
# 3488

# %%
seniorcitizen_no=df['Senior Citizen'].tolist().count('Yes') #CALCULATING SENIOR CITIZEN NUMBER
seniorcitizen_no
# Out:
# 1142

# %%
total=female_no+seniorcitizen_no     #TOTAL NUMBER OF SENIOR CITIZENS AND FEMALES.
total
# Out:
# 4630

# %%
female_per=female_no*100/total     #CALUCLATING FEMALE PERCENTAGE
female_per
# Out:
# 75.33477321814254

# %%
seniorcitizen_per=seniorcitizen_no*100/total   #CALCULATING SENIOR CITIZEN PERCENTAGE
seniorcitizen_per
# Out:
# 24.665226781857452

# %%
data = [female_per,seniorcitizen_per]
label = ['FEMALE PERCENTAGE','SENIOR CITIZEN PERCENTAGE']
 
plt.pie(data, labels=label, autopct='%1.1f%%', explode=[0,0.1], shadow=True, startangle=90) #PIE CHART TO SHOW PERCENTAGE WISE DISTRIBUTION
plt.title('FEMALE PERCENTAGE VS SENIOR CITIZEN PERCENTAGE')
plt.axis('equal')
plt.show()

# %% [markdown]
# #Q3 Explanation:
# According to the qns what i understood is given below.
#
# 1.Firstly am going to calculate the percentage of females and senior citizens.
#
# 2.Secondly We have to check for how many females and senior citizens are  present in this data set.
# So to know this i'm gng to calculate the female count,sc count and total.
#
# 3.Later percentage for females and senior citizens.
# As per the data I have observed that femles and senior citizens are categorical data types.So am using Pie plot.

# %% [markdown]
# #4.Please create an appropriate plot to examine the distribution of the tenure month column and explain the distribution. Based on distribution, perform appropriate statistical measures. Please also explain if the variable is symmetric or skewed. Please calculate it. Explain everything as asked.

# %%
sns.histplot(data=df,x="Tenure Months")

# %%
df["Tenure Months"].describe()
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: Tenure Months, dtype: float64

# %%
df["Tenure Months"].median()
# Out:
# 29.0

# %%
df["Tenure Months"].mode()
# Out:
# 0    1
# dtype: int64

# %%
df["Tenure Months"].skew()
# Out:
# 0.2395397495619829

# %% [markdown]
# #Q4 Explanation:
# 1.Firstly Tenure Months column is Numerical so that I have used Hist plot.
#
# 2.As per the above plot If skewness is in between −½ and +½, the distribution is approximately symmetric.Here the data is not very much deviated and  it looks like symmetrical only.
#
# 3.As per the 1st point,here data is numerical.So now we  are  performing the statistical measures.(In q2 I had  clearly explained about what are statistical measures)
#
# 4.Finally we are calculating the skewness for Tenure Months.So Skewness value = 0.239540.

# %% [markdown]
# #5.Please convert all binary columns into 0 and 1 using appropriate programming constructs, not one by one.

# %%
x=[col for col in df if (len(df[col].value_counts()) > 0) & all(df[col].value_counts().index.isin([0, 1]))]
x
# Out:
# ['Count', 'Churn Value']

# %% [markdown]
# #6.Please examine the distribution of monthly charges between males and females using box plots. Please explain the results also.

# %%
plt.figure(figsize=(9, 7)) #size of the plot
sns.boxplot(data=df,x="Gender", y="Monthly Charges") #box plot for monthly charges between Males and Females.
plt.title("Monthly Charges VS Gender")  # title of the plot.
# Out:
# Text(0.5, 1.0, 'Monthly Charges VS Gender')

# %% [markdown]
# #Q6 Explanation:
# As from the above plot we can see that the distribution for Monthly Charges between male and female is almost same.Hence we can say that it is symmetrical also.

# %% [markdown]
# #7.Please find what is the minimum total charges for Los Angeles city. Please find which zip code has the maximum total charges

# %%
clos=df.groupby(by="City")["Total Charges"].min()
clos["Los Angeles"]
# Out:
# ' '

# %%
zt=df[["Zip Code", "Total Charges"]].groupby(['Zip Code'], as_index=False).sum().sort_values(by='Total Charges', ascending=False)
zt.head(1)
# Out:
#      Zip Code                     Total Charges
# 382     92173  999.454732.352511.31593.13366.05

# %% [markdown]
#  zip code 92173 has maximum total charges that is 999.454

# %% [markdown]
# #8.Please find which payment method has the highest churn score and which has the lowest churn score.

# %%
CS_PM= df[["Churn Score","Payment Method"]]
CS_PM
# Out:
#       Churn Score             Payment Method
# 0              86               Mailed check
# 1              67           Electronic check
# 2              86           Electronic check
# 3              84           Electronic check
# 4              89  Bank transfer (automatic)
# ...           ...                        ...
# 7038           45  Bank transfer (automatic)
# 7039           59               Mailed check
# 7040           71    Credit card (automatic)
# 7041           59           Electronic check
# 7042           38  Bank transfer (automatic)
#
# [7043 rows x 2 columns]

# %%
Max_churn =CS_PM.sort_values(["Churn Score","Payment Method"],ascending=False)
Max_churn.head(1)
# Out:
#      Churn Score Payment Method
# 189          100   Mailed check

# %%
Max_churn =CS_PM.sort_values(["Churn Score"],ascending=False)
Max_churn.head(1)
# Out:
#      Churn Score    Payment Method
# 780          100  Electronic check

# %%
Min_churn = CS_PM.sort_values(["Churn Score"])
Min_churn.head(1)
# Out:
#       Churn Score           Payment Method
# 2148            5  Credit card (automatic)

# %% [markdown]
# #Q8 Explanation:
# From the above we can see that Mailed check and Electronic check has the highest churn score and credit card has lowest churn score.

# %% [markdown]
# #9.Please create an appropriate plot to check the count of payment methods and explain it.

# %%
plt.figure(figsize=(9, 7)) #size of the plot
sns.countplot(df['Payment Method'], hue="Payment Method", data = df ) #plotting the count plot
plt.title("Count VS Payment Method") #title of the plot
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Count VS Payment Method')

# %% [markdown]
# #Q9 Explanation:
# 1.From the Q1 we know that Payment Methods comes under categorical data type.So i'm using count plot.
#
# 2.The above plot shows the count of each payment methods.
#
# 3.Also electronic check has the highest count followed by mailed check and credit card has the lowest count

# %% [markdown]
# #10.Please create an appropriate plot to see the relationship between monthly charges and total charges.

# %%
plt.figure(figsize=(9, 7)) #size of the plot
sns.scatterplot(data=df,x="Total Charges", y="Monthly Charges") #scatter plot for relationship b/w monthly charges and total charges.
plt.title("Monthly Charges VS Total Charges")  # title of the plot.
# Out:
# Text(0.5, 1.0, 'Monthly Charges VS Total Charges')

# %% [markdown]
# #Q10 Explanation:
# 1.As per the Q1 we have seen that Monthly charges and Total charges comes under Numerical data type.
#
# 2.So to see the relationship between numerical data we  have to use Scatter plot .
